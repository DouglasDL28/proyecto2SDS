# %%
import pandas as pd
import numpy as np
from constants import db_types

# %% [markdown]
# ## Split
# Debido a la alta cantidad de datos que se tienen y el poco poder computacional con el que se cuenta se reducira las 8,921,483 a que sea 1/64 para poder manejarlo en el pre procesamiento de igual manera con el test set

# %%
malware_data_train = pd.read_csv('train.csv', dtype=db_types)
malware_data_test = pd.read_csv('test.csv', dtype=db_types)

# %%
count = int(malware_data_test.shape[0]/128)
new_test = malware_data_test.sample(n = count, random_state = 12)
new_test
# Out:
#                         MachineIdentifier   ProductName EngineVersion  \
# 627911   146f38712346ae58eb2f3e222d913cfe  win8defender   1.1.15200.1
# 7268545  eced01286c9b49c9b9a1b339296511f8  win8defender   1.1.15400.5
# 5898020  c04433153cb10d495025bd5cfee5f4f6  win8defender   1.1.15300.6
# 1299991  2a55148504ac886486cc340f930f50fe  win8defender   1.1.15300.6
# 2481813  50e2caf1b5e63bcd04463e99199ed3a9  win8defender   1.1.15300.6
# ...                                   ...           ...           ...
# 6450943  d24b9081951577984d7a212edf6dead8  win8defender   1.1.15400.5
# 7654567  f9822a72f6e3d8cb29f934116ad47944  win8defender   1.1.15200.1
# 6495682  d3c2110de5e627d5bccea004057c0e70  win8defender   1.1.15300.6
# 5997380  c3836a382ef258ed247fc57bbbceb30a  win8defender   1.1.15300.6
# 6613153  d797b359295251d02be83c6eaaedd750  win8defender   1.1.15400.4
#
#               AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# ...

# %%
count = int(malware_data_train.shape[0]/128)
grouped = malware_data_train.groupby('HasDetections', group_keys=False)
new_train = grouped.apply(lambda x: x.sample(min(len(x), count), random_state = 12))
new_train
# Out:
#                         MachineIdentifier   ProductName EngineVersion  \
# 8580390  f6349f44c52d69e41b22f1906a99b2a3  win8defender   1.1.15100.1
# 550980   0fd6d1876546211bd7f1013e001a2d16  win8defender   1.1.15200.1
# 2467937  46cacc0e4a424bb5fef07d127e9bfc27  win8defender   1.1.14405.2
# 4368470  7d62dff04e9db44eca7597ef8097d15e  win8defender   1.1.15200.1
# 4152733  772913940b6fb45fa81aeb56080222ef  win8defender   1.1.15100.1
# ...                                   ...           ...           ...
# 3564687  664f34c887269f4c6035e2ea80184f99  win8defender   1.1.15100.1
# 6821739  c3c20ed75f9bef9c6bb7da2df08ce7a3  win8defender   1.1.15000.2
# 8044821  e6d38ee8d9e049a87458d530d48ede8b  win8defender   1.1.15200.1
# 1966055  386c39f1241c3d03c030ba42b6d7fadb  win8defender   1.1.15000.2
# 5064090  9155a9f23c554c89922d9d0257154cba  win8defender   1.1.14600.4
#
#               AppVersion  AvSigVersion  IsBeta  RtpStateBitfield  \
# ...

# %%
new_train.groupby('HasDetections', group_keys=False).count()
# Out:
#                MachineIdentifier  ProductName  EngineVersion  AppVersion  \
# HasDetections
# 0.0                        69699        69699          69699       69699
# 1.0                        69699        69699          69699       69699
#
#                AvSigVersion  IsBeta  RtpStateBitfield  IsSxsPassiveMode  \
# HasDetections
# 0.0                   69699   69699             69427             69699
# 1.0                   69699   69699             69471             69699
#
#                DefaultBrowsersIdentifier  AVProductStatesIdentifier  ...  \
# HasDetections                                                        ...
# 0.0                                 3622                      69333  ...
# 1.0                                 3085                      69465  ...
#
#                Census_FirmwareManufacturerIdentifier  \
# HasDetections
# 0.0                                            68058
# 1.0                                            68537
#
# ...

# %%
new_test.columns
# Out:
# Index(['MachineIdentifier', 'ProductName', 'EngineVersion', 'AppVersion',
#        'AvSigVersion', 'IsBeta', 'RtpStateBitfield', 'IsSxsPassiveMode',
#        'DefaultBrowsersIdentifier', 'AVProductStatesIdentifier',
#        'AVProductsInstalled', 'AVProductsEnabled', 'HasTpm',
#        'CountryIdentifier', 'CityIdentifier', 'OrganizationIdentifier',
#        'GeoNameIdentifier', 'LocaleEnglishNameIdentifier', 'Platform',
#        'Processor', 'OsVer', 'OsBuild', 'OsSuite', 'OsPlatformSubRelease',
#        'OsBuildLab', 'SkuEdition', 'IsProtected', 'AutoSampleOptIn', 'PuaMode',
#        'SMode', 'IeVerIdentifier', 'SmartScreen', 'Firewall', 'UacLuaenable',
#        'Census_MDC2FormFactor', 'Census_DeviceFamily',
#        'Census_OEMNameIdentifier', 'Census_OEMModelIdentifier',
#        'Census_ProcessorCoreCount', 'Census_ProcessorManufacturerIdentifier',
#        'Census_ProcessorModelIdentifier', 'Census_ProcessorClass',
# ...

# %%
new_train.to_csv('new_train.csv')

# %%
new_test.to_csv('new_test.csv')
